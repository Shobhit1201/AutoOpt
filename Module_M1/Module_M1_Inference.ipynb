# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Nougat_scratch_temp1
# Out:
# /content/drive/MyDrive/Nougat_scratch_temp1

# %%
# %cd nougat-latex-ocr
# Out:
# /content/drive/MyDrive/Nougat_scratch_temp1/nougat-latex-ocr

# %%
# !pip install -r all_requirements.txt

# %%
# train script
# !CUDA_LAUNCH_BLOCKING=1 python /content/drive/MyDrive/Nougat_scratch_temp1/nougat-latex-ocr/tools/train_experiment.py --config_file /content/drive/MyDrive/Nougat_scratch_temp1/nougat-latex-ocr/config/base.yaml --phase 'train'

# %%
# %cd /content/drive/MyDrive/Nougat_scratch_temp1/nougat-latex-ocr
# Out:
# /content/drive/MyDrive/Nougat_scratch_temp1/nougat-latex-ocr

# %%
#inference

import sys
sys.path.append('/content/drive/MyDrive/Nougat_scratch_temp1/nougat-latex-ocr')


# !python examples/hybrid_inference.py \
    --img_folder "path/to/test/Images" \
    --gt_file "path/to/test/Latex.txt" \
    --checkpoint_path "path/to/weights.pth" \
    --device "cuda" \
    --config_source "Norm/nougat-latex-base"
