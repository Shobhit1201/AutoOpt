# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/OriginalNougat

# %%
# %cd nougat-latex-ocr

# %%
# !pip install -r all_requirements.txt

# %%
# Finetuning Script

# !CUDA_LAUNCH_BLOCKING=1 python /content/drive/MyDrive/OriginalNougat/nougat-latex-ocr/tools/train_experiment.py --config_file /content/drive/MyDrive/OriginalNougat/nougat-latex-ocr/config/base.yaml --phase 'train'

# %%
# Inference

import sys
sys.path.append('/content/drive/MyDrive/OriginalNougat/nougat-latex-ocr')

# !python examples/run_latex_ocr_with_METRIC.py \
    --img_folder  "path/to/test/images" \
    --gt_file "path/to/test/latex.txt" \
    --checkpoint_path "path/to/finetuned/weights.pth" \
    --device "cuda" \
    --config_source "Norm/nougat-latex-base"
